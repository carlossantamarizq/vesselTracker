# %%
import torch
import pandas

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path=r"G:\Mi unidad\Data\Simulations\yolov5s\weights\best.pt", force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\Equipo/.cache\torch\hub\master.zip
# YOLOv5  2022-5-9 torch 1.10.2+cpu CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
directory = r'C:\Users\Equipo\OneDrive - Universidad Politécnica de Madrid\Python\vesselTracker\Images\Gibraltar'

os.listdir(directory)
# Out:
# ['ejemplo.png',
#  'ejemplo2.png',
#  'ejemplo3.png',
#  'gibraltar_1-20190104-182541.png',
#  'gibraltar_10-20190112-061828.png',
#  'gibraltar_100-20190516-182542.png',
#  'gibraltar_101-20190517-062641.png',
#  'gibraltar_102-20190517-181804.png',
#  'gibraltar_103-20190518-061916.png',
#  'gibraltar_104-20190522-182605.png',
#  'gibraltar_105-20190522-182630.png',
#  'gibraltar_106-20190523-062737.png',
#  'gibraltar_107-20190523-181736.png',
#  'gibraltar_108-20190524-061829.png',
#  'gibraltar_109-20190528-182542.png',
#  'gibraltar_11-20190116-182541.png',
#  'gibraltar_110-20190529-062641.png',
#  'gibraltar_111-20190529-181804.png',
#  'gibraltar_112-20190530-061917.png',
#  'gibraltar_113-20190603-182605.png',
#  'gibraltar_114-20190603-182630.png',
#  'gibraltar_115-20190604-062737.png',
#  'gibraltar_116-20190604-181737.png',
#  'gibraltar_117-20190605-061830.png',
#  'gibraltar_118-20190609-182543.png',
#  'gibraltar_119-20190610-062642.png',
# ...

# %%
# Images

dir = r"C:\Users\Equipo\OneDrive - Universidad Politécnica de Madrid\Python\vesselTracker\Images\Split"
filenames = os.listdir(dir)

images = [os.path.join(dir, filename) for filename in filenames]
# Inference
results = model(images)

# Results


results.save()
# Out:
# Saved 12 images to runs\detect\exp4

# %%
results.pandas().xyxy[2]
# Out:
#           xmin        ymin        xmax        ymax  confidence  class    name
# 0   118.541229  141.630676  157.446411  167.295883    0.769647      0  vessel
# 1   199.420578  649.500916  225.625443  694.064758    0.749227      0  vessel
# 2   626.775818   35.892765  666.300537   83.091896    0.737636      0  vessel
# 3   274.710052  782.375366  293.534790  807.665222    0.675883      0  vessel
# 4   263.914795  688.106995  287.667267  709.668152    0.669343      0  vessel
# 5   135.180908  845.947937  154.795547  879.530945    0.604582      0  vessel
# 6   847.093933   98.356560  869.326782  121.519646    0.580924      0  vessel
# 7   944.431641  475.079651  964.454529  491.308197    0.376341      0  vessel
# 8   903.563843  518.585876  925.358337  535.344849    0.319033      0  vessel
# 9   519.783203  877.238281  549.425659  905.320740    0.287908      0  vessel
# 10  893.142944  562.481506  912.311707  580.059021    0.256109      0  vessel

# %%
results[0].show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Equipo\OneDrive - Universidad Politécnica de Madrid\Python\vesselTracker\train.ipynb Cell 7' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Equipo/OneDrive%20-%20Universidad%20Polit%C3%A9cnica%20de%20Madrid/Python/vesselTracker/train.ipynb#ch0000006?line=0'>1</a> results[0].show()
#
# TypeError: 'Detections' object is not subscriptable
